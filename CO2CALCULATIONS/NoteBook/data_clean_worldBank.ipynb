# %%
import pandas as pd
data = pd.read_csv("/home/cj/Bureau/Master2/bdp/database/world_bank_database.csv", sep=',', header=0)

# %%
data.head()
# Out:
#   '"Country Name"' '"1960"' '"1961"' '"1962"' '"1963"' '"1964"' '"1965"'  \
# 0        '"Aruba"'     '""'     '""'     '""'     '""'     '""'     '""'
# 1  '"Afghanistan"'     '""'     '""'     '""'     '""'     '""'     '""'
# 2       '"Angola"'     '""'     '""'     '""'     '""'     '""'     '""'
# 3      '"Albania"'     '""'     '""'     '""'     '""'     '""'     '""'
# 4      '"Andorra"'     '""'     '""'     '""'     '""'     '""'     '""'
#
#   '"1966"' '"1967"' '"1968"'  ...        '"2004"'        '"2005"'  \
# 0     '""'     '""'     '""'  ...            '""'            '""'
# 1     '""'     '""'     '""'  ...   '"14654.374"'  '"14770.2643"'
# 2     '""'     '""'     '""'  ...  '"36860.2334"'  '"35855.7384"'
# 3     '""'     '""'     '""'  ...  '"7401.10155"'   '"8308.3856"'
# 4     '""'     '""'     '""'  ...            '""'            '""'
#
#          '"2006"'       '"2007"'        '"2008"'              '"2009"'  \
# ...

# %%
columns_name = ['Country name']
for i in range(2014-1960): columns_name.append(1960+i)

# %%
data.columns = columns_name
data.head()
# Out:
#       Country name  1960  1961  1962  1963  1964  1965  1966  1967  1968  ...  \
# 0        '"Aruba"'  '""'  '""'  '""'  '""'  '""'  '""'  '""'  '""'  '""'  ...
# 1  '"Afghanistan"'  '""'  '""'  '""'  '""'  '""'  '""'  '""'  '""'  '""'  ...
# 2       '"Angola"'  '""'  '""'  '""'  '""'  '""'  '""'  '""'  '""'  '""'  ...
# 3      '"Albania"'  '""'  '""'  '""'  '""'  '""'  '""'  '""'  '""'  '""'  ...
# 4      '"Andorra"'  '""'  '""'  '""'  '""'  '""'  '""'  '""'  '""'  '""'  ...
#
#              2004            2005            2006           2007  \
# 0            '""'            '""'            '""'           '""'
# 1   '"14654.374"'  '"14770.2643"'  '"14849.1594"'  '"15272.633"'
# 2  '"36860.2334"'  '"35855.7384"'   '"36375.822"'  '"36690.534"'
# 3  '"7401.10155"'   '"8308.3856"'  '"8027.14955"'  '"9879.3935"'
# 4            '""'            '""'            '""'           '""'
#
#              2008                  2009                  2010  \
# ...

# %%
import math
def regex_number(text):
    modif_text = re.sub("[^0-9]", "", text)
    if modif_text is '': return math.nan
    else: return float(modif_text)

# %%
data.columns[1:data.shape[1]]
# Out:
# Index([1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971,
#        1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983,
#        1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995,
#        1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007,
#        2008, 2009, 2010, 2011, 2012, 2013],
#       dtype='object')

# %%
for i in data.columns[1:data.shape[1]]: data[i] = data[i].apply(regex_number)

# %%
data.head()
# Out:
#       Country name  1960  1961  1962  1963  1964  1965  1966  1967  1968  ...  \
# 0        '"Aruba"'   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1  '"Afghanistan"'   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2       '"Angola"'   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3      '"Albania"'   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4      '"Andorra"'   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#           2004         2005         2006        2007         2008  \
# 0          NaN          NaN          NaN         NaN          NaN
# 1   14654374.0  147702643.0  148491594.0  15272633.0  152887756.0
# 2  368602334.0  358557384.0   36375822.0  36690534.0   37396294.0
# 3  740110155.0   83083856.0  802714955.0  98793935.0    8136785.0
# 4          NaN          NaN          NaN         NaN          NaN
#
#            2009          2010          2011          2012  2013
# ...

# %%
def country_column(text):
    return text.replace('\'', '')[1:-1:]

# %%
data['Country name'] = data['Country name'].apply(country_column)

# %%
data.head()
# Out:
#   Country name  1960  1961  1962  1963  1964  1965  1966  1967  1968  ...  \
# 0        Aruba   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1  Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2       Angola   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3      Albania   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4      Andorra   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#           2004         2005         2006        2007         2008  \
# 0          NaN          NaN          NaN         NaN          NaN
# 1   14654374.0  147702643.0  148491594.0  15272633.0  152887756.0
# 2  368602334.0  358557384.0   36375822.0  36690534.0   37396294.0
# 3  740110155.0   83083856.0  802714955.0  98793935.0    8136785.0
# 4          NaN          NaN          NaN         NaN          NaN
#
#            2009          2010          2011          2012  2013
# ...

# %%
data = data.drop([1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 2013], axis=1)

# %%
data
# Out:
#      Country name          1970          1971         1972          1973  \
# 0           Aruba  4.230630e+08  4.278695e+08  432866131.0  4.372459e+08
# 1     Afghanistan  1.430662e+08  1.439178e+08   13040848.0  1.353575e+08
# 2          Angola  6.064860e+09  3.916217e+09  422056507.0  4.425267e+09
# 3         Albania  6.960868e+07  6.950036e+07   76132661.0  7.348492e+07
# 4         Andorra           NaN           NaN          NaN           NaN
# ..            ...           ...           ...          ...           ...
# 259        Kosovo           NaN           NaN          NaN           NaN
# 260          Yeme           NaN  4.839521e+07   50991964.0  5.353746e+07
# 261  South Africa  2.537697e+08  2.504188e+08  250958915.0  2.692785e+08
# 262        Zambia  2.341681e+07  1.325747e+08  142670635.0  1.531198e+08
# 263      Zimbabwe  2.403393e+07  2.140487e+07     212314.0  2.315625e+07
#
#             1974          1975          1976          1977          1978  ...  \
# ...

# %%
data.to_csv(r'/home/cj/Bureau/Master2/bdp/database/world_bank_clean_database.csv', na_rep='nan', header = True)

# %%
new_data = pd.read_csv("/home/cj/Bureau/Master2/bdp/database/world_bank_clean_database.csv", sep=',')
new_data = new_data.drop(new_data.columns[0], axis=1)

# %%
new_data
# Out:
#      Country name          1970          1971         1972          1973  \
# 0           Aruba  4.230630e+08  4.278695e+08  432866131.0  4.372459e+08
# 1     Afghanistan  1.430662e+08  1.439178e+08   13040848.0  1.353575e+08
# 2          Angola  6.064860e+09  3.916217e+09  422056507.0  4.425267e+09
# 3         Albania  6.960868e+07  6.950036e+07   76132661.0  7.348492e+07
# 4         Andorra           NaN           NaN          NaN           NaN
# ..            ...           ...           ...          ...           ...
# 259        Kosovo           NaN           NaN          NaN           NaN
# 260          Yeme           NaN  4.839521e+07   50991964.0  5.353746e+07
# 261  South Africa  2.537697e+08  2.504188e+08  250958915.0  2.692785e+08
# 262        Zambia  2.341681e+07  1.325747e+08  142670635.0  1.531198e+08
# 263      Zimbabwe  2.403393e+07  2.140487e+07     212314.0  2.315625e+07
#
#             1974          1975          1976          1977          1978  ...  \
# ...
